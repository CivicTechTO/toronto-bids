# %%
import pandas as pd
import re
from bs4 import BeautifulSoup
from pathlib import Path

# %%
results = []

# %%
# Out:
# data/Doc3883459616/MANIFEST_Attachments _2 of 2_.html
# data/Doc3883459616/MANIFEST_Attachments _1 of 2_.html
# data/Doc3883709991/MANIFEST_Attachment _2 of 3_.html
# data/Doc3883709991/MANIFEST_Attachment _1 of 3_.html
# data/Doc3883709991/MANIFEST_Attachment _3 of 3_.html

# %%
df = pd.DataFrame(results)

# %%
df.to_csv('data_summary.csv')

# %%
df
# Out:
#                 ID                                              title  \
# 0    Doc3715319439  RFQ for Fill Removal from Various Toronto Wate...
# 1    Doc3499844881  Request for Quotations for Supply and Installa...
# 2    Doc3646133737  RFT for Local Road Resurfacing and Reconstruct...
# 3    Doc2989612087  Request for Tenders for Baycrest Park Revitali...
# 4    Doc3521913233  Request for Tender for TTC Track, Watermain, R...
# ..             ...                                                ...
# 541  Doc3694847548  Request for Quotation for Gas Detection System...
# 542  Doc3512316715  Request for Tenders for Interim Repairs and Ma...
# 543  Doc3374301730  RFT for  Ashbridges Bay Treatment Plant Boiler...
# 544  Doc3434771966  Request for Quotations for Safety Data Sheet W...
# 545  Doc3865027173  Request for Quotation for Vision Zero - School...
#
#                  Opportunity Amount: Contract Length:  \
# 0    $1,500.00 to $99,000,000.00 CAD        12 months
# 1    $1,000.00 to $99,000,000.00 CAD        24 months
# 2    $1,500.00 to $99,000,000.00 USD         1 months
# 3    $1,000.00 to $99,000,000.00 CAD        18 months
# 4    $1,500.00 to $99,000,000.00 CAD         1 months
# ..                               ...              ...
# 541  $1,500.00 to $99,000,000.00 CAD        36 months
# 542  $1,500.00 to $99,000,000.00 CAD              NaN
# 543  $1,500.00 to $99,000,000.00 CAD        48 months
# 544  $1,000.00 to $99,000,000.00 CAD        36 months
# 545  $1,500.00 to $99,000,000.00 CAD         7 months
#
#            Response Deadline:              Posting ID:  \
# 0      6 Dec 2022 9:00 AM PST  14483251(Doc3715319439)
# 1     16 Sep 2022 9:00 AM PDT  13670403(Doc3499844881)
# 2      6 Oct 2022 9:00 AM PDT  14101481(Doc3646133737)
# 3    14 Apr 2022 10:41 AM PDT  12408182(Doc3338887534)
# 4     22 Jul 2022 9:00 AM PDT  13313110(Doc3521913233)
# ..                        ...                      ...
# 541   28 Feb 2023 9:00 AM PST  15226146(Doc3694847548)
# 542   7 Jul 2022 12:33 PM PDT  13273461(Doc3512316715)
# 543    9 May 2022 8:59 PM PDT  12428591(Doc3374301730)
# 544    7 Jun 2022 8:59 PM PDT  12977905(Doc3434771966)
# 545    9 Mar 2023 9:00 AM PST  15428893(Doc3865027173)
#
#                Posting Type:                          Public Posting:  \
# 0    Request for Information  http://discovery.ariba.com/rfx/14483251
# 1    Request for Information  http://discovery.ariba.com/rfx/13670403
# 2    Request for Information  http://discovery.ariba.com/rfx/14101481
# 3      Request for Quotation  http://discovery.ariba.com/rfx/12408182
# 4      Request for Quotation  http://discovery.ariba.com/rfx/13313110
# ..                       ...                                      ...
# 541  Request for Information  http://discovery.ariba.com/rfx/15226146
# 542  Request for Information  http://discovery.ariba.com/rfx/13273461
# 543    Request for Quotation  http://discovery.ariba.com/rfx/12428591
# 544  Request for Information  http://discovery.ariba.com/rfx/12977905
# 545  Request for Information  http://discovery.ariba.com/rfx/15428893
#
#                                     Product Categories  \
# 0    [Plumbing or sewer inspection service, Highway...
# 1    [Water treatment services, Service water, Supp...
# 2                [Highway or road paving or surfacing]
# 3    [Building construction management, Parks, Park...
# 4                      [Sidewalk or curb construction]
# ..                                                 ...
# 541  [Toxic gas detection services, Engineering equ...
# 542  [Highway or road paving or surfacing, Foundati...
# 543  [Demolition services, Power plant construction...
# 544  [Document management software, Data center ser...
# 545                        [Pavement marking services]
#
#                                                summary  \
# 0    \nPlease disregard the Ariba Discovery posting...
# 1    \nThe scope of this RFQ is for the supply and ...
# 2    \nPlease disregard the Ariba Discovery posting...
# 3    \nTo the following pre-qualified Suppliers to ...
# 4    \nRequest for Tender for TTC Track, Watermain,...
# ..                                                 ...
# 541  \nThis Request for Quotation (the “RFQ”) is an...
# 542  \n  Request for Tenders for Interim Repairs an...
# 543  \nRequest for Tenders for Ashbridges Bay Treat...
# 544  \nThe scope of this RFQ is for Safety Data She...
# 545  \nThe non-exclusive supply and custom applicat...
#
#                               Company Public Profile: Match Confidence:  \
# 0                                                 NaN               NaN
# 1    http://discovery.ariba.com/profile/AN01050912625                0%
# 2    http://discovery.ariba.com/profile/AN01050912625                0%
# 3    http://discovery.ariba.com/profile/AN01050912625                0%
# 4    http://discovery.ariba.com/profile/AN01050912625                0%
# ..                                                ...               ...
# 541  http://discovery.ariba.com/profile/AN01050912625                0%
# 542  http://discovery.ariba.com/profile/AN01050912625                0%
# 543  http://discovery.ariba.com/profile/AN01050912625                0%
# 544  http://discovery.ariba.com/profile/AN01050912625                0%
# 545  http://discovery.ariba.com/profile/AN01050912625                0%
#
#     Award Date: Business Contact:
# 0           NaN               NaN
# 1           NaN               NaN
# 2           NaN               NaN
# 3           NaN               NaN
# 4           NaN               NaN
# ..          ...               ...
# 541         NaN            Fei He
# 542         NaN               NaN
# 543         NaN               NaN
# 544         NaN               NaN
# 545         NaN   Richard Hampton
#
# [546 rows x 14 columns]
